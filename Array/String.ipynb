# %% [markdown]
# ### EASY

# %%
# 1.Reverse the string 
name = str(input("Enter the string"))
reverse = name[::-1]
print(reverse)
# Out:
# raqaw

# %%
# Reverse without indentation 

string = 'name'
reverse = ''
for i in string:
    reverse =  i + reverse
print(reverse)
# Out:
# eman

# %%
# 2. S
