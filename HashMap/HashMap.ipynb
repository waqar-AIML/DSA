# %% [markdown]
# ### WORKING OF HASHMAP

# %%
# Implement Hash Table
def get_hash(key):
    hash = 0
    for char in key:
        hash += ord(char) # Here ord will give the Unicode value for each char and sum it 
    return hash % 100 # The total sum is then done modulus by no of memory space to get the index value 
    
get_hash('march 6')
# Out:
# 9

# %%
# working of the get hash
o1 = ord('m') # 109
o2 = ord('a') # 97
o3 = ord('r') # 114
o4 = ord('c') # 99
o5 = ord('h') # 104
o6 = ord('6') # 54
o7 = ord (' ') # 32
o7

test_sum = 109 + 97 + 114+ 99 + 104 + 54 + 32
mod = test_sum % 100
mod # 9
# here 9 will be the index no where the value which is assigned to 'march 6' is stored
# Out:
# 9

# %%
# How all method for Hash table works 
class HashTable:
    def __init__(self):
        self.max = 10 # Memory space 
        self.arr = [None for i in range(self.max)] # assigning none value to all the 100 array memory index

    def get_hash(self,key): # function to get the index of each key where it will be stored 
        hash = 0
        for char in key:
            hash += ord(char)
        return hash % self.max 

    def __getitem__(self, index):
        h = self.get_hash(index)
        return self.arr[h] 

    def __setitem__(self, key, val): # assigning the value to the index which is calculated 
        h = self.get_hash(key)
        self.arr[h] = val 

    def __delitem__(self, key): # deleting the value from the index
        h = self.get_hash(key)
        self.arr[h] = None

# %%
# Testing 
H = HashTable()
H.get_hash('march 6')
H["march 6"] = 310 # for getitem

# %%
H.arr
# Out:
# [None, None, None, None, None, None, None, None, None, 310]

# %%
del H["march 6"]

# %%
H.arr
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# Hash Table Collision Handling Using Chaining

class HashTable:
    def __init__(self):
        self.max = 10
        self.arr = [[] for i in range(self.max)]

    def get_hash(self,key):
        hash = 0 
        for char in key:
            hash += ord(char)
        return hash % self.max

    def __getitem__(self, key):
        arr_index = self.get_hash(key)
        for k in self.arr[arr_index]: 
            if k[0] == key:
                return k[1]

    def __setitem__(self,key, val):
        h = self.get_hash(key)
        found = False
        for idx, element in enumerate(self.arr[h]):
            if len(element)==2 and element[0] == key:
                self.arr[h][idx] = (key,val)
                found = True
        if not found:
            self.arr[h].append((key,val))

    def __delitem__(self, key):
        arr_index = self.get_hash(key)
        for index, kv in enumerate(self.arr[arr_index]):
            if kv[0] == key:
                print("del",index)
                del self.arr[arr_index][index]

# %%
t = HashTable()
t["march 6"] = 310
t["march 7"] = 420

# %%
t.arr
# Out:
# [[('march 7', 420)], [], [], [], [], [], [], [], [], [('march 6', 310)]]

# %%
t["march 8"] = 67
t["march 17"] = 63457

# %%
t.arr
# Out:
# [[('march 7', 420)],
#  [('march 8', 67)],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('march 6', 310), ('march 17', 63457)]]

# %%
del t["march 6"]
t.arr
# Out:
# del 0
# [[('march 7', 420)],
#  [('march 8', 67)],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [('march 17', 63457)]]

# %% [markdown]
# ### PRACTISE QUESTIONS

# %% [markdown]
# ### 1. nyc_weather.csv contains new york city weather for first few days in the month of January. Write a program that can answer following

# %%
# 1.1 What was the average temperature in first week of Jan

nyc_weather = {}
temperature = []
with open("nyc_weather.csv", 'r') as f:
    next(f)
    for line in f:
        day = line.split(',')
        date = day[0]
        temp = int(day[1])
        temperature.append(int(day[1]))
        nyc_weather[date] = temp

nyc_weather
# Out:
# {'Jan 1': 27,
#  'Jan 2': 31,
#  'Jan 3': 23,
#  'Jan 4': 34,
#  'Jan 5': 37,
#  'Jan 6': 38,
#  'Jan 7': 29,
#  'Jan 8': 30,
#  'Jan 9': 35,
#  'Jan 10': 30}

# %%
temperature
# Out:
# [27, 31, 23, 34, 37, 38, 29, 30, 35, 30]

# %%
avg_temp = sum(temperature[0:7])/ len(temperature[0:7])
avg_temp
# Out:
# 31.285714285714285

# %%
# 1.3 Figure out data structure that is best for this problem

# %% [markdown]
# ### EASY

# %%
# 1. Find the Sum of All the Items in a Dictionary
d={'A':100,'B':540,'C':239}

# def sum(input):
#     Total = 0
#     for v in d.values():
#         Total += v
#     return Total    

# print(sum(d))

# Another way 
Total = sum(d.values())
print(Total)
# Out:
# 879

# %%
# 2. Multiply All the Items in a Dictionary
d={'A':1,'B':5,'C':2}

def multiply(input):
    output = 1
    for v in input.values():
        output = v * output
    return output

print(multiply(d))    

# Another way 
from math import prod
def multiply(input):
    output = prod(input.values())
    return output

print(multiply(d))
# Out:
# 10
# 10

# %%
# From a dictionary of items and prices, create a new dictionary with items priced above 100.
dic = {'laptop': 800, 'book': 40, 'phone': 600, 'pen': 10}

def new_dict(input):

# %%
#15 write a funtion where we will check the key in dictionary have values then we will do some operation other wise exit
dic = {'Name':'waqar' , 'Marks':[30,40,60,20], 'location':'Bangalore', 'car':"tata"}

# %%
#17 Intermediate Question

sales = [
    {'product': 'A', 'price': 100, 'quantity': 2},
    {'product': 'B', 'price': 50, 'quantity': 5},
    {'product': 'A', 'price': 100, 'quantity': 3},
    {'product': 'C', 'price': 200, 'quantity': 1},
    {'product': 'B', 'price': 50, 'quantity': 2},
]

# output {'A': 500, 'B': 350, 'C': 200}

# %%
# 18
"""#Write a function that performs the following cleaning steps:
If a rating is None or an empty string, set it to 0.
If is_active is a string (e.g., 'True', 'False'), convert it to a boolean value.""""AB Testing"
users = [
    {'name': 'Alice', 'rating': 4.5, 'is_active': 'True'},
    {'name': 'Bob', 'rating': None, 'is_active': 'False'},
    {'name': 'Charlie', 'rating': 3.0, 'is_active': True},
    {'name': 'David', 'rating': '', 'is_active': 'True'},
]

# %%
#20 You are given a list of dictionaries, where each dictionary represents a city with its name and temperature. 
# Use a list comprehension to create a new list containing only the names of the cities with a temperature above 20 degrees Celsius.

cities = [
    {'name': 'London', 'temp': 15},
    {'name': 'Paris', 'temp': 22},
    {'name': 'Tokyo', 'temp': 28},
    {'name': 'New York', 'temp': 18},
]

# %%
# 22 Flatning the dictionary
example = {
    1:{
        'header':'H1',
        'body':'B1',
        'footer':'F1'
    },
    2:{'header':'H2',
        'body':'B2',
        'table': 'T1',
        'footer':'F2'
    }
}

# output = [[1,H1,B1,F1], [2,H2,B2,T1,F2]]

# %%
# if some more nested dictionary is added to flatten 
example = {
    1:{
        'header':'H1',
        'body':'B1',
        'footer':'F1'
    },
    2:{'header':'H2',
        'body':'B2',
        'table': {'r1': 100 , 'r2': 200, 'r3':{'rr1': 1000}},
        'footer':'F2'
    }
}

# output = [[1,H1,B1,F1], [2,H2,B2,100,200,1000,F2]]
