# %% [markdown]
# # 1 Let us say your expense for every month are listed below,
# January - 2200
# February - 2350
# March - 2600
# April - 2130
# May - 2190

# %% [markdown]
# ### CREATED LIST USING DICTIONARY

# %%
# Create a list
monthly_expenses = [{'January':2200, 'February':2350, 'March':2600, 'April':2130, 'May':2190}]
print(monthly_expenses)
# Out:
# [{'January': 2200, 'February': 2350, 'March': 2600, 'April': 2130, 'May': 2190}]

# %%
# 1. In Feb, how many dollars you spent extra compare to January?
print(monthly_expenses[0]['February'] - monthly_expenses[0]['January'])
# Out:
# 150

# %%
# 2. Find out your total expense in first quarter (first three months) of the year.
total_expense_first_quarter = monthly_expenses[0]['January'] + monthly_expenses[0]['February'] + monthly_expenses[0]['March']
print(total_expense_first_quarter)
# Out:
# 7150

# %%
# 3. Find out if you spent exactly 2000 dollars in any month
for month, expense in monthly_expenses[0].items():
    if expense == 2000:
        print(f"You spent exactly 2000 dollars in {month}.")
        break

# %% [markdown]
# ### CREATED ARRAY USING NUMBERS AND ANSWER THE QUESTIONS

# %%
monthly_expenses_1 = [2200, 2350, 2600, 2130, 2190]
print(monthly_expenses_1)
# Out:
# [2200, 2350, 2600, 2130, 2190]

# %%
# 1. In Feb, how many dollars you spent extra compare to January?
print(monthly_expenses_1[1] - monthly_expenses_1[0])
# Out:
# 150

# %%
# 2. Find out your total expense in first quarter (first three months) of the year.
total_expense_q1 = monthly_expenses_1[0] + monthly_expenses_1[1] + monthly_expenses_1[2]
print(total_expense_q1)
# Out:
# 7150

# %%
# 3. Find out if you spent exactly 2000 dollars in any month

for spend in monthly_expenses_1:
    if spend == 2000:
        print("yes i have spent 2000")
        break

else:
    print("NO i have not spend 2000 in any month")
# Out:
# NO i have not spend 2000 in any month

# %%
# 4. June month just finished and your expense is 1980 dollar. Add this item to our monthly expense list
monthly_expenses_1.append(1980)
# Out:
# [2200, 2350, 2600, 2130, 2190, 1980, 1980]

# %%
monthly_expenses_1
# Out:
# [2200, 2350, 2600, 2130, 2190, 1980, 1980]

# %%
# 5. You returned an item that you bought in a month of April and
# got a refund of 200$. Make a correction to your monthly expense list
# based on this

monthly_expenses_1[3] = monthly_expenses_1[3] -200 
monthly_expenses_1
# Out:
# [2200, 2350, 2600, 1930, 2190, 1980, 1980]

# %% [markdown]
# ## 2. You have a list of your favourite marvel super heros.
# heros=['spider man','thor','hulk','iron man','captain america']

# %%
heros=['spider man','thor','hulk','iron man','captain america']
print(heros)
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america']

# %%
# 1. Length of the list
print(len(heros))
# Out:
# 5

# %%
# 2. Add 'black panther' at the end of this list
def add(hero):
    heros.append(hero)
    return heros

print(add('black panther'))
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america', 'black panther']

# %%
# 3. You realize that you need to add 'black panther' after 'hulk',
#    so remove it from the list first and then add it after 'hulk'

# removing
# heros.pop()
print(heros)

#
# Out:
# ['spider man', 'thor', 'hulk', 'iron man', 'captain america']
